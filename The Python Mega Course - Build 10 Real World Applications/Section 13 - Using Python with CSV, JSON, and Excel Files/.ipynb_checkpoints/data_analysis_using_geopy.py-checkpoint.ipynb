# %%
import os
os.listdir()
# Out:
# ['filtering_data.py.ipynb',
#  '.DS_Store',
#  'supermarkets.json',
#  'supermarkets.csv',
#  'loading_excel_files.ipynb',
#  'supermarkets-semi-colons.txt',
#  'loading_json_files.ipynb',
#  'ipython.py',
#  'supermarkets.xlsx',
#  'loading_csv_files.ipynb',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'loading_txt_files.ipynb',
#  'data.txt',
#  'jupyter.py']

# %%
import pandas

# %%
df7 = pandas.read_csv("data.txt", header = None)
df7
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df7.columns = ["ID", "Address", "City", "ZIP", "Country", "Name", "Employees"]
df7
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7.set_index("Address", inplace = True)
df7
# Out:
#                  ID           City               ZIP Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df7.loc["735 Dolores St":"332 Hill St","City":"ZIP"]
# Out:
#                          City               ZIP
# Address
# 735 Dolores St  San Francisco          CA 94119
# 332 Hill St     San Francisco  California 94114

# %%
df7.loc["3666 21st St","ZIP"]
# Out:
# 'CA 94114'

# %%
df7.loc[:,"Country"]
# Out:
# Address
# 3666 21st St       USA
# 735 Dolores St     USA
# 332 Hill St        USA
# 3995 23rd St       USA
# 1056 Sanchez St    USA
# 551 Alvarado St    USA
# Name: Country, dtype: object

# %%
list(df7.loc[:,"Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df7.iloc[1:3,1:3]
# Out:
#                          City               ZIP
# Address
# 735 Dolores St  San Francisco          CA 94119
# 332 Hill St     San Francisco  California 94114

# %%
df7.iloc[1:4,1:4]
# Out:
#                          City               ZIP Country
# Address
# 735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St     San Francisco  California 94114     USA
# 3995 23rd St    San Francisco          CA 94114     USA

# %%
df7.iloc[:,1:4]
# Out:
#                           City               ZIP Country
# Address
# 3666 21st St     San Francisco          CA 94114     USA
# 735 Dolores St   San Francisco          CA 94119     USA
# 332 Hill St      San Francisco  California 94114     USA
# 3995 23rd St     San Francisco          CA 94114     USA
# 1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St  San Francisco          CA 94114     USA

# %%
df7.iloc[3,1:4]
# Out:
# City       San Francisco
# ZIP             CA 94114
# Country              USA
# Name: 3995 23rd St, dtype: object

# %%
df7.drop("City", 1)
# Out:
# /var/folders/1n/xgz_qd31509d_fgnnlx940fc0000gn/T/ipykernel_14809/1050542670.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df7.drop("City", 1)
#                  ID               ZIP Country         Name  Employees
# Address
# 3666 21st St      1          CA 94114     USA      Madeira          8
# 735 Dolores St    2          CA 94119     USA  Bready Shop         15
# 332 Hill St       3  California 94114     USA  Super River         25
# 3995 23rd St      4          CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5        California     USA      Sanchez         12
# 551 Alvarado St   6          CA 94114     USA   Richvalley         20

# %%
df7.drop("332 Hill St", 0)
# Out:
# /var/folders/1n/xgz_qd31509d_fgnnlx940fc0000gn/T/ipykernel_14809/2385247462.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df7.drop("332 Hill St", 0)
#                  ID           City         ZIP Country         Name  Employees
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley         20

# %%
df7
# Out:
#                  ID           City         ZIP Country         Name  Employees
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley         20

# %%
df7.drop(df7.index[0:3], 0)
# Out:
# /var/folders/1n/xgz_qd31509d_fgnnlx940fc0000gn/T/ipykernel_14809/3085681069.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df7.drop(df7.index[0:3], 0)
#                  ID           City         ZIP Country        Name  Employees
# Address
# 1056 Sanchez St   5  San Francisco  California     USA     Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA  Richvalley         20

# %%
df7.drop(df7.columns[0:3], 1)
# Out:
# /var/folders/1n/xgz_qd31509d_fgnnlx940fc0000gn/T/ipykernel_14809/1576349032.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df7.drop(df7.columns[0:3], 1)
#                 Country         Name  Employees
# Address
# 3666 21st St        USA      Madeira          8
# 735 Dolores St      USA  Bready Shop         15
# 3995 23rd St        USA   Ben's Shop         10
# 1056 Sanchez St     USA      Sanchez         12
# 551 Alvarado St     USA   Richvalley         20

# %%
df7.columns
# Out:
# Index(['ID', 'City', 'ZIP', 'Country', 'Name', 'Employees'], dtype='object')

# %%
df7
# Out:
#                  ID           City         ZIP Country         Name  Employees
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley         20

# %%
df7 = pandas.read_csv("data.txt", header = None)
df7
df7.columns = ["ID", "Address", "City", "ZIP", "Country", "Name", "Employees"]
df7
df7.set_index("Address", inplace = True)
df7
# Out:
#                  ID           City               ZIP Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df7["Continent"] = df7.shape[0]*["North America"]
df7
# Out:
#                  ID           City               ZIP Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees      Continent
# Address
# 3666 21st St             8  North America
# 735 Dolores St          15  North America
# 332 Hill St             25  North America
# 3995 23rd St            10  North America
# 1056 Sanchez St         12  North America
# 551 Alvarado St         20  North America

# %%
df7.shape
# Out:
# (6, 7)

# %%
df7.shape[0]
# Out:
# 6

# %%
df7["Continent"] = df7["Country"] + ", " + "North America"

# %%
df7
# Out:
#                  ID           City               ZIP Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees           Continent
# Address
# 3666 21st St             8  USA, North America
# 735 Dolores St          15  USA, North America
# 332 Hill St             25  USA, North America
# 3995 23rd St            10  USA, North America
# 1056 Sanchez St         12  USA, North America
# 551 Alvarado St         20  USA, North America

# %%
df7_t = df7.T

# %%
df7_t
# Out:
# Address          3666 21st St      735 Dolores St         332 Hill St  \
# ID                          1                   2                   3
# City            San Francisco       San Francisco       San Francisco
# ZIP                  CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# ID                          4                   5                   6
# City            San Francisco       San Francisco       San Francisco
# ZIP                  CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# ...

# %%
df7_t["My Address"] = [7, "My City", "My ZIP", "My Country", "My Shop", 10, "My Continent"]

# %%
df7_t
# Out:
# Address          3666 21st St      735 Dolores St         332 Hill St  \
# ID                          1                   2                   3
# City            San Francisco       San Francisco       San Francisco
# ZIP                  CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St  \
# ID                          4                   5                   6
# City            San Francisco       San Francisco       San Francisco
# ZIP                  CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# ...

# %%
df7 = df7_t.T

# %%
df7
# Out:
#                 ID           City               ZIP     Country         Name  \
# Address
# 3666 21st St     1  San Francisco          CA 94114         USA      Madeira
# 735 Dolores St   2  San Francisco          CA 94119         USA  Bready Shop
# 332 Hill St      3  San Francisco  California 94114         USA  Super River
# 3995 23rd St     4  San Francisco          CA 94114         USA   Ben's Shop
# 1056 Sanchez St  5  San Francisco        California         USA      Sanchez
# 551 Alvarado St  6  San Francisco          CA 94114         USA   Richvalley
# My Address       7        My City            My ZIP  My Country      My Shop
#
#                 Employees           Continent
# Address
# 3666 21st St            8  USA, North America
# 735 Dolores St         15  USA, North America
# 332 Hill St            25  USA, North America
# 3995 23rd St           10  USA, North America
# 1056 Sanchez St        12  USA, North America
# 551 Alvarado St        20  USA, North America
# ...

# %%
dm = pandas.read_csv("supermarkets-semi-colons.txt", sep=";")
dm
# Out:
#    ID          Address         City_x     State_x Country_x       Name_x  \
# 0   2   735 Dolores St  San Francisco    CA 94119       USA  Bready Shop
# 1   4     3995 23rd St  San Francisco    CA 94114       USA   Ben's Shop
# 2   5  1056 Sanchez St  San Francisco  California       USA      Sanchez
# 3   6  551 Alvarado St  San Francisco    CA 94114       USA   Richvalley
#
#    Employees_x         City_y Country_y  Emplyees_y       Name_y     State_y  \
# 0           15  San Francisco       USA          15  Bready Shop    CA 94119
# 1           10  San Francisco       USA          10   Ben's Shop    CA 94114
# 2           12  San Francisco       USA          12      Sanchez  California
# 3           20  San Francisco       USA          20   Richvalley    CA 94114
#
#             Continent
# 0  USA, North America
# 1  USA, North America
# 2  USA, North America
# 3  USA, North America

# %%
from geopy.geocoders import ArcGIS

# %%
nom = ArcGIS()

# %%
nom.geocode("3995 23rd St, San Francisco, CA 94114")
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.75292099814533, -122.43170295955227, 0.0))

# %%
n = nom.geocode("735 Dolores St, San Francisco, CA 94119")
print(n) # when address doesn't exist
# Out:
# 735 Dolores St, San Francisco, California, 94110

# %%
n = nom.geocode("3995 23rd St, San Francisco, CA 94114")

# %%
n.latitude
# Out:
# 37.75292099814533

# %%
n.longitude
# Out:
# -122.43170295955227

# %%
type(n)
# Out:
# geopy.location.Location

# %%
import pandas
df = pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"] = df["Address"] + "," + df["City"] + "," + df["State"] + "," + df["Country"]
df
# Out:
#    ID                                         Address           City  \
# 0   1         3666 21st St,San Francisco,CA 94114,USA  San Francisco
# 1   2       735 Dolores St,San Francisco,CA 94119,USA  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA  San Francisco
# 3   4         3995 23rd St,San Francisco,CA 94114,USA  San Francisco
# 4   5    1056 Sanchez St,San Francisco,California,USA  San Francisco
# 5   6      551 Alvarado St,San Francisco,CA 94114,USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"] = df["Address"].apply(nom.geocode)
df
# Out:
#    ID                                         Address           City  \
# 0   1         3666 21st St,San Francisco,CA 94114,USA  San Francisco
# 1   2       735 Dolores St,San Francisco,CA 94119,USA  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA  San Francisco
# 3   4         3995 23rd St,San Francisco,CA 94114,USA  San Francisco
# 4   5    1056 Sanchez St,San Francisco,California,USA  San Francisco
# 5   6      551 Alvarado St,San Francisco,CA 94114,USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# 0  (3666 21st St, San Francisco, California, 9411...
# ...

# %%
df.Coordinates
# Out:
# 0    (3666 21st St, San Francisco, California, 9411...
# 1    (735 Dolores St, San Francisco, California, 94...
# 2    (332 Hill St, San Francisco, California, 94114...
# 3    (3995 23rd St, San Francisco, California, 9411...
# 4    (1056 Sanchez St, San Francisco, California, 9...
# 5    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
df.Coordinates[0]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.756632001957215, -122.42941101194798, 0.0))

# %%
df["Latitude"] = df["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df["Longitude"] = df["Coordinates"].apply(lambda x: x.longitude if x != None else None)
df
# Out:
#    ID                                         Address           City  \
# 0   1         3666 21st St,San Francisco,CA 94114,USA  San Francisco
# 1   2       735 Dolores St,San Francisco,CA 94119,USA  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA  San Francisco
# 3   4         3995 23rd St,San Francisco,CA 94114,USA  San Francisco
# 4   5    1056 Sanchez St,San Francisco,California,USA  San Francisco
# 5   6      551 Alvarado St,San Francisco,CA 94114,USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
